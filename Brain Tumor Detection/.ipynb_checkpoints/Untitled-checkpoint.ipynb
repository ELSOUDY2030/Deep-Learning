# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import pandas as pd
import matplotlib.colors as Colormap
import seaborn as sns
import os

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from keras import layers
from keras import utils

# %%
data_dir = 'Training\\'
width = 180
batch_size = 32
train_ds = tf.keras.utils.image_dataset_from_directory(data_dir,
                                                       validation_split=0.2,
                                                       subset="training",
                                                       seed=42,
                                                       image_size=(width,width),
                                                       batch_size=batch_size


)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.

# %%
data_dir = 'Training\\'
width = 180
batch_size = 32
val_ds = tf.keras.utils.image_dataset_from_directory(data_dir,
                                                       validation_split=0.2,
                                                       subset="validation",
                                                       seed=42,
                                                       image_size=(width,width),
                                                       batch_size=batch_size


)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.

# %%
# Get labels inferred by the method itself
class_names = train_ds.class_names
print(class_names)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
train_ds_labels = []
for _,labels in train_ds:
    for i in range(len(labels)):
        train_ds_labels.append(class_names[labels[i].numpy()])

# %%
# Create a function to customize autopct parameter of plt.pie()
def make_autopct(values):
    def my_autopct(pct):
        # The pct is percentage value that matplotlib supplies for every wedge
        total = sum(values)
        val = int(round(pct*total/100.0))
        return f'{pct:.2f}%  ({val})'
    return my_autopct

# %%
df = pd.DataFrame({'Category':train_ds_labels})

# %%
cat = df.Category.value_counts().index.to_list()
cat = [i.title() for i in cat]
count = df.Category.value_counts().to_list()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(8,8))
plt.pie(count,labels=cat,shadow=True,autopct=make_autopct(count))
plt.title('Distribution')
plt.show()

# %%
plt.figure(figsize=(15,8))
for image, labels in train_ds.take(23):
    for i in range(15):
        ax = plt.subplot(3,5,1+i)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.axis('off')
        plt.title(class_names[labels[i]],fontsize=12,pad=8)
plt.subplots_adjust(wspace=0.25, hspace=0.25)
plt.show()

# %%
Autotune = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=Autotune)
val_ds = val_ds.cache().prefetch(buffer_size=Autotune)

# %%
Normalization_layers = layers.Rescaling(1/255)

data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal',
                     input_shape=(width,width,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
def plot_images_augmented(dataset):
    """
    Parameters:
    : dataset - dataset of type `tf.data.Dataset` 
                with images to plot
    """
    plt.figure(figsize=(10, 10))
    for images, _ in dataset.take(1):
        for i in range(9):
            augmented_images = data_augmentation(images)
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(augmented_images[0].numpy().astype("uint8"))
            plt.axis("off")

# %%
plot_images_augmented(train_ds)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
num_classes = len(class_names)
model = keras.Sequential([
    data_augmentation,
    Normalization_layers,
    layers.Conv2D(16,3,padding='same',activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    
    layers.Conv2D(32,3,padding='same',activation='relu'),    
    layers.MaxPooling2D(pool_size=(2,2)),
    
    layers.Conv2D(64,3,padding='same',activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),    
    
    layers.Dropout(0.2),
    layers.Flatten(),
    
    layers.Dense(128,activation='relu'),
    layers.Dense(num_classes, name='output')
   
    
])
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
model.compile(optimizer='adam',
             loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  output (Dense)              (None, 4)                 516
#
# =================================================================
# Total params: 3,989,156
# Trainable params: 3,989,156
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = keras.callbacks.ModelCheckpoint('brainT_detect.h5')

early_stop = keras.callbacks.EarlyStopping(patience=10,
                                          restore_best_weights=True)

# %%
his_model = model.fit(train_ds,
                     validation_data=val_ds,
                     epochs=100,
                     callbacks=[checkpoint,early_stop])
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 143/143 [==============================] - 42s 230ms/step - loss: 0.8688 - accuracy: 0.6396 - val_loss: 0.7753 - val_accuracy: 0.7189
# Epoch 2/100
# 143/143 [==============================] - 31s 215ms/step - loss: 0.5620 - accuracy: 0.7897 - val_loss: 0.5580 - val_accuracy: 0.7872
# Epoch 3/100
# 143/143 [==============================] - 30s 214ms/step - loss: 0.4752 - accuracy: 0.8195 - val_loss: 0.5388 - val_accuracy: 0.8214
# Epoch 4/100
# 143/143 [==============================] - 31s 216ms/step - loss: 0.4117 - accuracy: 0.8486 - val_loss: 0.5593 - val_accuracy: 0.8100
# Epoch 5/100
# 143/143 [==============================] - 31s 216ms/step - loss: 0.3664 - accuracy: 0.8646 - val_loss: 0.9318 - val_accuracy: 0.7014
# Epoch 6/100
# 143/143 [==============================] - 31s 214ms/step - loss: 0.3296 - accuracy: 0.8748 - val_loss: 0.4432 - val_accuracy: 0.8292
# Epoch 7/100
# 143/143 [==============================] - 31s 217ms/step - loss: 0.2927 - accuracy: 0.8880 - val_loss: 0.8816 - val_accuracy: 0.7259
# Epoch 8/100
# 143/143 [==============================] - 30s 209ms/step - loss: 0.2879 - accuracy: 0.8926 - val_loss: 0.4593 - val_accuracy: 0.8389
# Epoch 9/100
# 143/143 [==============================] - 31s 220ms/step - loss: 0.2406 - accuracy: 0.9123 - val_loss: 0.3836 - val_accuracy: 0.8590
# Epoch 10/100
# 143/143 [==============================] - 31s 218ms/step - loss: 0.2218 - accuracy: 0.9208 - val_loss: 0.3487 - val_accuracy: 0.8792
# Epoch 11/100
# 143/143 [==============================] - 31s 215ms/step - loss: 0.1986 - accuracy: 0.9252 - val_loss: 0.5675 - val_accuracy: 0.8100
# Epoch 12/100
# 143/143 [==============================] - 32s 221ms/step - loss: 0.2000 - accuracy: 0.9214 - val_loss: 0.4180 - val_accuracy: 0.8687
# Epoch 13/100
# 143/143 [==============================] - 31s 216ms/step - loss: 0.1722 - accuracy: 0.9365 - val_loss: 0.4342 - val_accuracy: 0.8564
# Epoch 14/100
# 143/143 [==============================] - 30s 211ms/step - loss: 0.1697 - accuracy: 0.9374 - val_loss: 0.2881 - val_accuracy: 0.9107
# Epoch 15/100
# 143/143 [==============================] - 30s 211ms/step - loss: 0.1529 - accuracy: 0.9431 - val_loss: 0.3715 - val_accuracy: 0.8783
# Epoch 16/100
# 143/143 [==============================] - 31s 216ms/step - loss: 0.1434 - accuracy: 0.9479 - val_loss: 0.2985 - val_accuracy: 0.9133
# Epoch 17/100
# 143/143 [==============================] - 31s 216ms/step - loss: 0.1301 - accuracy: 0.9532 - val_loss: 0.2689 - val_accuracy: 0.9221
# Epoch 18/100
# 143/143 [==============================] - 31s 218ms/step - loss: 0.1250 - accuracy: 0.9538 - val_loss: 0.3183 - val_accuracy: 0.9028
# Epoch 19/100
# 143/143 [==============================] - 32s 225ms/step - loss: 0.1219 - accuracy: 0.9575 - val_loss: 0.3599 - val_accuracy: 0.8949
# Epoch 20/100
# 143/143 [==============================] - 31s 215ms/step - loss: 0.1082 - accuracy: 0.9635 - val_loss: 0.2921 - val_accuracy: 0.9159
# Epoch 21/100
# 143/143 [==============================] - 31s 215ms/step - loss: 0.1011 - accuracy: 0.9639 - val_loss: 0.2865 - val_accuracy: 0.9256
# Epoch 22/100
# 143/143 [==============================] - 31s 214ms/step - loss: 0.0935 - accuracy: 0.9678 - val_loss: 0.3011 - val_accuracy: 0.9098
# Epoch 23/100
# 143/143 [==============================] - 31s 214ms/step - loss: 0.0897 - accuracy: 0.9698 - val_loss: 0.3545 - val_accuracy: 0.8993
# Epoch 24/100
# 143/143 [==============================] - 31s 216ms/step - loss: 0.0925 - accuracy: 0.9650 - val_loss: 0.2979 - val_accuracy: 0.9177
# Epoch 25/100
# 143/143 [==============================] - 31s 214ms/step - loss: 0.0821 - accuracy: 0.9698 - val_loss: 0.2744 - val_accuracy: 0.9238
# Epoch 26/100
# 143/143 [==============================] - 31s 214ms/step - loss: 0.0805 - accuracy: 0.9718 - val_loss: 0.3612 - val_accuracy: 0.8993
# Epoch 27/100
# 143/143 [==============================] - 31s 216ms/step - loss: 0.0783 - accuracy: 0.9740 - val_loss: 0.3183 - val_accuracy: 0.9308

# %%
epochs = len(his_model.epoch) # epochs completed by early stopping
accuracy = his_model.history['accuracy']
val_acc = his_model.history['val_accuracy']

loss = his_model.history['loss']
val_loss = his_model.history['val_loss']

epochs_range = range(epochs)

# Plot training and validation accuracy
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save("brainT_detect.h5")
